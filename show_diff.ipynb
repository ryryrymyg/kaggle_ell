# %%
import pandas as pd

# %%
diff = pd.read_csv('diff.csv')

# %%
display(diff)
# Out:
#       Unnamed: 0         id  case_num  pn_num  feature_num  \
# 0              4  00016_004         0      16            4
# 1              9  00016_009         0      16            9
# 2             10  00016_010         0      16           10
# 3             16  00041_003         0      41            3
# 4             24  00041_011         0      41           11
# ...          ...        ...       ...     ...          ...
# 4159       14273  95330_907         9   95330          907
# 4160       14278  95330_912         9   95330          912
# 4161       14279  95330_913         9   95330          913
# 4162       14283  95333_900         9   95333          900
# 4163       14296  95333_913         9   95333          913
#
#                                              annotation  \
# 0              ['felt as if he were going to pass out']
# 1            ['palpitations', 'heart beating/pounding']
# 2                                     ['3-4 months of']
# ...
